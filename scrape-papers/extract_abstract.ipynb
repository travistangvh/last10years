# %% [markdown]
# Instructions from Prof:
#
# Alrighty y’all, with about a month left in the semester (how? HOW??), please read through this document for the next steps I’m envisioning:
# https://gtvault-my.sharepoint.com/:w:/g/personal/aduncan9_gatech_edu/ERDbeQND2pdJsK77-9HTWqwBkCYJ4zXoB-66jYMcCF1LmA?e=7b0Nim
# And thanks for the suggestions on coding topics! I revised the topics a bit, trying to take into account what’s interesting, what are somewhat "hot topics", and what topics should have enough papers to actually find meaningful trends. I restricted it to 4 topics because [see previous comment about there only being a month left in the semester].
#
# What this notebook does:
# 1. Read in the list of L@S papers provided by prof. This document does not include abstract (this is "prof_df" in this notebook)
# 2. Extract all L@S papers from Scopus manually. This document includes abstract (this is "df" in this notebook)
# 3. Use fuzzywuzzy to match df with prof_df using the title of the papers, so that we have the abstract for every paper in prof_df.
# 4. Export document.

# %%
import pandas as pd

# %%
import pandas as pd
# Downloaded from Scopus
# https://www.scopus.com/results/results.uri?sort=plf-f&src=s&st1=Developing+Student%27s+Global+Competencies+at+Scale+in+an+Affordable+MOOC+K12+Outreach+Initiative&sid=80ba9e19ec822c92b36edfab5890b776&sot=b&sdt=b&sl=105&s=%28KEY%28l%40s+2016%29+OR+SRCTITLE%28l%40s+2017%29+OR+SRCTITLE%28l%40s+2022%29%29&origin=searchbasic&editSaveSearch=&yearFrom=Before+1960&yearTo=Present&sessionSearchId=80ba9e19ec822c92b36edfab5890b776&limit=10
# By searching "source title l@s OR source title learning at scale"
df = pd.read_csv('input/all_papers.csv')
# df = df.dropna(subset=['Author full names']) # there are empty results

# %%
df['Source title'].unique()
# Out:
# array(['L@S 2022 - Proceedings of the 9th ACM Conference on Learning @ Scale',
#        'L@S 2023 - Proceedings of the 10th ACM Conference on Learning @ Scale',
#        'Improving Student Learning at Scale: a How-To Guide for Higher Education',
#        'L@S 2021 - Proceedings of the 8th ACM Conference on Learning @ Scale',
#        'L@S 2020 - Proceedings of the 7th ACM Conference on Learning @ Scale',
#        'Proceedings of the 6th 2019 ACM Conference on Learning at Scale, L@S 2019',
#        'Proceedings of the 5th Annual ACM Conference on Learning at Scale, L at S 2018',
#        'L@S 2017 - Proceedings of the 4th (2017) ACM Conference on Learning at Scale',
#        'L@S 2016 - Proceedings of the 3rd 2016 ACM Conference on Learning at Scale',
#        'L@S 2015 - 2nd ACM Conference on Learning at Scale',
#        'L@S 2014 - Proceedings of the 1st ACM Conference on Learning at Scale'],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['Authors', 'Author full names', 'Author(s) ID', 'Title', 'Year',
#        'Source title', 'Volume', 'Issue', 'Art. No.', 'Page start', 'Page end',
#        'Page count', 'Cited by', 'DOI', 'Link', 'Affiliations',
#        'Authors with affiliations', 'Abstract', 'Author Keywords',
#        'Index Keywords', 'Molecular Sequence Numbers', 'Chemicals/CAS',
#        'Tradenames', 'Manufacturers', 'Funding Details', 'Funding Texts',
#        'References', 'Correspondence Address', 'Editors', 'Publisher',
#        'Sponsors', 'Conference name', 'Conference date', 'Conference location',
#        'Conference code', 'ISSN', 'ISBN', 'CODEN', 'PubMed ID',
#        'Language of Original Document', 'Abbreviated Source Title',
#        'Document Type', 'Publication Stage', 'Open Access', 'Source', 'EID'],
#       dtype='object')

# %%
df['Abstract']
# Out:
# 0      Embedding a post recommendation system in onli...
# 1      The popularity of Massive Open Online Courses ...
# 2      The emerging field of affordable degrees at sc...
# 3      The United States is experiencing a shortage o...
# 4      In past work, time management interventions in...
#                              ...
# 673    This paper discusses learning at scale from th...
# 674    Rapid feedback is a core component of mastery ...
# 675    An efficient peer grading mechanism is propose...
# 676    For an instructor who is teaching a massive op...
# 677                              [No abstract available]
# Name: Abstract, Length: 678, dtype: object

# %%
# Prof's document
# Extracte from https://gtvault-my.sharepoint.com/personal/aduncan9_gatech_edu/_layouts/15/onedrive.aspx?ga=1&id=%2Fpersonal%2Faduncan9%5Fgatech%5Fedu%2FDocuments%2FConferences%20and%20Journals%2FLearning%20at%20Scale%202024%2FTeam%20documents%2FPapers
# The name of document is "Paper list.xlsx"
prof_df = pd.read_csv('input/prof_doc.csv')
prof_df
# Out:
#                                            Paper Title  Year  \
# 0    Student skill and goal achievement in the mapp...  2014
# 1    Correlating Skill and Improvement in 2 MOOCs w...  2014
# 2    Demographic differences in how students naviga...  2014
# 3    Understanding in-video dropouts and interactio...  2014
# 4    How video production affects student engagemen...  2014
# ..                                                 ...   ...
# 557             Towards Game-based Assessment at Scale  2023
# 558  Towards Scalable Vocabulary Acquisition Assess...  2023
# 559  Towards the Identification of Experts in Infor...  2023
# 560  Unlocking Financial Success: Empowering Higher...  2023
# 561  Utilizing Neural Network to Predict Students A...  2023
#
#     Full Paper or WIP?                 Session Name  \
# 0           Full Paper  Student Skills and behavior
# 1           Full Paper  Student Skills and behavior
# 2           Full Paper  Student Skills and behavior
# 3           Full Paper             Course materials
# 4           Full Paper             Course materials
# ..                 ...                          ...
# 557         Full Paper            Works-in-Progress
# 558         Full Paper            Works-in-Progress
# 559         Full Paper            Works-in-Progress
# 560         Full Paper            Works-in-Progress
# 561         Full Paper            Works-in-Progress
#
#      Context: MOOCs, In-person degrees, Online degrees, K-12, Informal learning environments, Other (specify in 1-2 words in Context Notes)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 557                                                NaN
# 558                                                NaN
# 559                                                NaN
# 560                                                NaN
# 561                                                NaN
#
#      Context Notes  \
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ..             ...
# 557            NaN
# 558            NaN
# 559            NaN
# 560            NaN
# 561            NaN
#
#      Subject: CS, Non-CS STEM, Non-STEM (specify in 1-2 words in Subject Notes), Unspecified  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 557                                                NaN
# 558                                                NaN
# 559                                                NaN
# 560                                                NaN
# 561                                                NaN
#
#      Subject Notes  AI/ML Applications in Education? (Enter "Y" or "N")
# 0              NaN                                                NaN
# 1              NaN                                                NaN
# 2              NaN                                                NaN
# 3              NaN                                                NaN
# 4              NaN                                                NaN
# ..             ...                                                ...
# 557            NaN                                                NaN
# 558            NaN                                                NaN
# 559            NaN                                                NaN
# 560            NaN                                                NaN
# 561            NaN                                                NaN
#
# [562 rows x 9 columns]

# %%
# Match title of prof_df and df using fuzzywuzzy
from fuzzywuzzy import fuzz

# For each doc in prof_df (title in the column "Paper Title"), find the title of the most similar doc title from df["Title"] using fuzzywuzzy matching
# The similarity score is stored in the column "Similarity Score"
# The title of the most similar doc is stored in the column "Matched Title"
prof_df['Similarity Score'] = 0
prof_df['Matched Title'] = None

for i in range(len(prof_df)):
    max_score = 0
    matched_title = ''
    
    for j in range(len(df)):
        score = fuzz.ratio(prof_df.loc[i,'Paper Title'].lower(), df.loc[j,'Title'].lower())
        if score > max_score:
            max_score = score
            matched_title = df['Title'][j]

    # Assign the max score and matched title to the prof_df without raising slicing copy error
    prof_df.loc[i,'Similarity Score'] = max_score

    # If score is at least  70, then we consider it as a match
    if max_score >= 70:
        prof_df.loc[i,'Matched Title'] = matched_title
    
prof_df
# Out:
#                                            Paper Title  Year  \
# 0    Student skill and goal achievement in the mapp...  2014
# 1    Correlating Skill and Improvement in 2 MOOCs w...  2014
# 2    Demographic differences in how students naviga...  2014
# 3    Understanding in-video dropouts and interactio...  2014
# 4    How video production affects student engagemen...  2014
# ..                                                 ...   ...
# 557             Towards Game-based Assessment at Scale  2023
# 558  Towards Scalable Vocabulary Acquisition Assess...  2023
# 559  Towards the Identification of Experts in Infor...  2023
# 560  Unlocking Financial Success: Empowering Higher...  2023
# 561  Utilizing Neural Network to Predict Students A...  2023
#
#     Full Paper or WIP?                 Session Name  \
# 0           Full Paper  Student Skills and behavior
# 1           Full Paper  Student Skills and behavior
# 2           Full Paper  Student Skills and behavior
# 3           Full Paper             Course materials
# 4           Full Paper             Course materials
# ..                 ...                          ...
# 557         Full Paper            Works-in-Progress
# 558         Full Paper            Works-in-Progress
# 559         Full Paper            Works-in-Progress
# 560         Full Paper            Works-in-Progress
# 561         Full Paper            Works-in-Progress
#
#      Context: MOOCs, In-person degrees, Online degrees, K-12, Informal learning environments, Other (specify in 1-2 words in Context Notes)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 557                                                NaN
# 558                                                NaN
# 559                                                NaN
# 560                                                NaN
# 561                                                NaN
#
#      Context Notes  \
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ..             ...
# 557            NaN
# 558            NaN
# 559            NaN
# 560            NaN
# 561            NaN
#
#      Subject: CS, Non-CS STEM, Non-STEM (specify in 1-2 words in Subject Notes), Unspecified  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 557                                                NaN
# 558                                                NaN
# 559                                                NaN
# 560                                                NaN
# 561                                                NaN
#
#      Subject Notes  AI/ML Applications in Education? (Enter "Y" or "N")  \
# 0              NaN                                                NaN
# 1              NaN                                                NaN
# 2              NaN                                                NaN
# 3              NaN                                                NaN
# 4              NaN                                                NaN
# ..             ...                                                ...
# 557            NaN                                                NaN
# 558            NaN                                                NaN
# 559            NaN                                                NaN
# 560            NaN                                                NaN
# 561            NaN                                                NaN
#
#      Similarity Score                                      Matched Title
# 0                 100  Student skill and goal achievement in the mapp...
# 1                  99  Correlating skill and improvement in 2 MOOCs w...
# 2                 100  Demographic differences in how students naviga...
# 3                  99  Understanding in-video dropouts and interactio...
# 4                 100  How video production affects student engagemen...
# ..                ...                                                ...
# 557               100             Towards Game-based Assessment at Scale
# 558               100  Towards Scalable Vocabulary Acquisition Assess...
# 559               100  Towards the Identification of Experts in Infor...
# 560               100  Unlocking Financial Success: Empowering Higher...
# 561               100  Utilizing Neural Network to Predict Students A...
#
# [562 rows x 11 columns]

# %%
#Merge prof_df and df using "Matched Title"
merged_df = pd.merge(prof_df, df, how='left', left_on='Matched Title', right_on='Title')

# %%
cols = merged_df.columns

# Remove "Abstract" from cols
cols = cols.drop('Abstract')

# Add Abstract to be the fifth
cols = cols.insert(4, 'Abstract')

cols
# Out:
# Index(['Paper Title', 'Year_x', 'Full Paper or WIP?', 'Session Name',
#        'Abstract',
#        'Context: MOOCs, In-person degrees, Online degrees, K-12, Informal learning environments, Other (specify in 1-2 words in Context Notes)',
#        'Context Notes',
#        'Subject: CS, Non-CS STEM, Non-STEM (specify in 1-2 words in Subject Notes), Unspecified',
#        'Subject Notes', 'AI/ML Applications in Education? (Enter "Y" or "N")',
#        'Similarity Score', 'Matched Title', 'Authors', 'Author full names',
#        'Author(s) ID', 'Title', 'Year_y', 'Source title', 'Volume', 'Issue',
#        'Art. No.', 'Page start', 'Page end', 'Page count', 'Cited by', 'DOI',
#        'Link', 'Affiliations', 'Authors with affiliations', 'Author Keywords',
#        'Index Keywords', 'Molecular Sequence Numbers', 'Chemicals/CAS',
#        'Tradenames', 'Manufacturers', 'Funding Details', 'Funding Texts',
#        'References', 'Correspondence Address', 'Editors', 'Publisher',
#        'Sponsors', 'Conference name', 'Conference date', 'Conference location',
#        'Conference code', 'ISSN', 'ISBN', 'CODEN', 'PubMed ID',
#        'Language of Original Document', 'Abbreviated Source Title',
#        'Document Type', 'Publication Stage', 'Open Access', 'Source', 'EID'],
#       dtype='object')

# %%
# export prof_df to csv
merged_df[cols].to_csv('output/prof_df_with_additional_info.csv', index=False)

# %%
# Print all the matched titles as a sanity check
print(merged_df.sort_values('Similarity Score', ascending=True)[['Paper Title','Title','Similarity Score']].to_string())

# We can see that even the lowest similarity score has the correct title matched
# Out:
#                                                                                                                                                             Paper Title                                                                                                                                                               Title  Similarity Score
# 542                                                                                                                                                       Examinator v3                                                                                                                                                                 NaN                52
# 391                                                                                                                                    Teaching at Scale and Back Again                                                                                                                                                                 NaN                64
# 82                                                                                        Who You Are or What You Do: Comparing the Predictive Power of Demographics vs                             Who you are or what you do: Comparing the predictive power of demographics vs. activity patterns in massive open online courses (MOOCs)                73
# 556                                                                               The [email protected] Eight Years: A Review of Papers and Authors at Learning @ Scale                                                                                            The L@St Eight Years: A Review of Papers and Authors at Learning @ Scale                89
# 53                                                                                                                   Do Numeric Ratings Impact Peer Reviewers?  359-362                                                                                                                           Do numeric ratings impact peer reviewers?                90
# 472                                                                                                           Where's the Learning in Education Crowdsourcing?  305-308                                                                                                                    Where's the Learning in Education Crowdsourcing?                91
# 222                                                                                                          MOOC Dropout Prediction: How to Measure Accuracy?  161-164                                                                                                                   MOOC dropout prediction: How to measure accuracy?                92
# 156                                                                                                            Optimizing the Amount of Practice in an On-Line Platform                                                                                                   Optimizing the amount of practice in an on-line learning platform                93
# 198                                                                                                     Data-mining textual responses to uncover misconception patterns                                                                                            D.TRUMP: Data-mining textual responses to uncover misconception patterns                93
# 241                                                                               What are the Expectations of Disabled Learners when Participating in a MOOC?  225-228                                                                                        What are the expectations of disabled learners when participating in a MOOC?                94
# 418                                                                                      Code Free Chatbot Development: An Easy Way to Jumpstart Your Chatbot!  233-235                                                                                               Code Free Chatbot Development: An Easy Way to Jumpstart Your Chatbot!                94
# 404                                                                                                     Affordable Degrees at Scale: New Phenomenon or New Hype?  25-35                                                                                                            Affordable Degrees at Scale: New Phenomenon or New Hype?                94
# 515                                                                                      Should College Dropout Prediction Models Include Protected Attributes?  91-100                                                                                              Should College Dropout Prediction Models Include Protected Attributes?                95
# 149                                                                                                                          Metaphors for Learning and MOOC Pedagogies                                                                                                                            Metaphors for learning & MOOC Pedagogies                95
# 203                                                                    Do Performance Trends Suggest Wide-spread Collaborative Cheating on Asynchronous Exams?  111-120                                                                             Do performance trends suggest wide-spread collaborative cheating on asynchronous exams?                95
# 456                                                                   Supporting Learners' Self-regulation in LMOOCs: What Have We Done and How Far We Can Go?  207-209                                                                            Supporting Learners' Self-regulation in LMOOCs: What Have We Done and How Far We Can Go?                95
# 164                                                          Profiling MOOC Course Returners: How Does Student Behavior Change Between Two Course Enrollments?  269-272                                                                   Profiling MOOC course returners: How does student behavior change between two course enrollments?                96
# 295                                                                                                                    Supporting Answerers with Feedback in Social Q&A                                                                                                                  Supporting answerers with feedback in social QandA                96
# 312                                                                                Use expert knowledge instead of data – generating hints for Hour of Code exercises –                                                                                   Use expert knowledge instead of data-generating hints for Hour of Code exercises-                96
# 259          EdTech and Girls Education in Low- and Middle-Income Countries: Which Intervention Types Have the Greatest Impact on Learning Outcomes for Girls?  330-334                   EdTech and Girls Education in Low- and Middle-Income Countries: Which Intervention Types Have the Greatest Impact on Learning Outcomes for Girls?                97
# 536                            Does the Availability of Reattempts and Video Solutions Affect Learners' Voluntary Engagement with Mastery Learning Activities?  421-425                                     Does the Availability of Reattempts and Video Solutions Affect Learners' Voluntary Engagement with Mastery Learning Activities?                97
# 58                                                                                                                     Feature Factory: Crowd Sourced Feature Discovery                                                                                                                    Feature factory: Crowd-sourced feature discovery                98
# 387                                                                                                            The Relevance of Ivan Illich’s Learning Webs 50 Years On                                                                                                            The Relevance of Ivan Illich's Learning Webs 50 Years on                98
# 42                                                                    Are You Listening?: Social Roles and Perceived Value of Statements in Online Learning Communities                                                                    Are you listening? Social roles and perceived value of statements in online learning communities                99
# 380                                                             Crowdsourcing the Evaluation of Multiple-Choice Questions Using Item-Writing Flaws and Bloom’s Taxonomy                                                             Crowdsourcing the Evaluation of Multiple-Choice Questions Using Item-Writing Flaws and Bloom's Taxonomy                99
# 194                                                                                                            Collaboration and Teamwork on a MOOC Platform: A Toolset                                                                                                             Collaboration and teamwork on a MOOC platform a toolset                99
# 344                                                                                                  Chimeria:Grayscale MOOC: Towards Critical Self-Reflection at Scale                                                                                                 Chimeria: Grayscale MOOC: Towards critical self-reflection at scale                99
# 388                                                                                           Exploring Students’ Perceptions and Engagement in Hybrid Flexible Courses                                                                                           Exploring Students' Perceptions and Engagement in Hybrid Flexible Courses                99
# 375                                                                     Teaching C Programming Interactively at Scale Using Taskgrader: an Open-source Autograder Tool.                                                                      Teaching C programming interactively at scale using taskGrader: An Open-source Autograder Tool                99
# 182                                                                      A Crowdsourcing Approach to Collecting Tutorial Videos - Toward Personalized Learning-at-Scale                                                                       A crowdsourcing approach to collecting tutorial videos -Toward personalized learning-at-scale                99
# 365                                                                              Peer Advising at Scale: Content and Context of a LearnerOwned Course Evaluation System                                                                             Peer advising at scale: Content and context of a learner-owned course evaluation system                99
# 211                                                                      Getting to Know English Language Learners in MOOCs: Their Motivations, Behaviors, and Outcomes                                                                       Getting to know english language learners in MOOCs: Their motivations, behaviors and outcomes                99
# 206                                                         Epistemic Cognition: A Promising and Necessary Construct for Enriching Large-scale Online Learning Analysis                                                           Epistemic cognition: A promising and necessaryconstruct for enrichinglarge-scale online learning analysis                99
# 37                                                                                                                    A Modern Student Experience inSystems Programming                                                                                                                  A modern student experience in systems programming                99
# 501                                                                             Introducing Data Wrangling using Graphical Subgoals - Findings from an e-Learning Study                                                                               Introducing Data Wrangling using Graphical Subgoals-Findings from an e-Learning Study                99
# 232                                                                   Robust Evaluation Matrix: Towards a More Principled Offline Exploration of Instructional Policies                                                                    Robust evaluation matrix towards a more principled offline exploration of instructional policies                99
# 291                                                                     The Effects of Adaptive Learning in a Massive Open Online Course on Learners’ Skill Development                                                                     The effects of adaptive learning in a massive open online course on learners' skill development                99
# 307                                                                                    The unbearable lightness of consent: Mapping MOOC providers’ response to consent                                                                                    The unbearable lightness of consent: Mapping MOOC providers' response to consent                99
# 1                                                                                           Correlating Skill and Improvement in 2 MOOCs with a Student’s Time on Tasks                                                                                         Correlating skill and improvement in 2 MOOCs with a student's time on tasks                99
# 298                                                                                       Classifying and Visualizing Students’ Cognitive Engagement in Course Readings                                                                                       Classifying and visualizing students' cognitive engagement in course readings                99
# 309                                                           How a data-driven course planning tool affects college students’ GPA: Evidence from two field experiments                                                           How a data-driven course planning tool affects college students' GPA: Evidence from two field experiments                99
# 317                                                                                           Designing a Learning Analytics Dashboard for Twitter facilitated Teaching                                                                                           Designing a learning analytics dashboard for twitter-facilitated teaching                99
# 3                                                                                         Understanding in-video dropouts and interaction peaks inonline lecture videos                                                                                      Understanding in-video dropouts and interaction peaks in online lecture videos                99
# 389                                                        Managing TAs at Scale: Investigating the Experiences of Teaching Assistants in Introductory Computer Science                                                        Managing TAs at Scale: Investigating the Experiences of Teaching Assistants in Introductory Computer Science               100
# 299                                                                                           Squeezing the Limeade: Policies and Workflows for Scalable Online Degrees                                                                                           Squeezing the limeade: Policies and workflows for scalable online degrees               100
# 386                         From Answering for Points to Commenting for Others An Examination of the Posting Behaviors of High-reputation-score Users of Stack Overflow                        From Answering for Points to Commenting for Others: An Examination of the Posting Behaviors of High-reputation-score Users of Stack Overflow               100
# 385                                                                                          High-Resolution Course Feedback: Timely Feedback Mechanism for Instructors                                                                                          High-Resolution Course Feedback: Timely Feedback Mechanism for Instructors               100
# 384                                                                                             How Common are Common Wrong Answers? Crowdsourcing Remediation at Scale                                                                                             How Common are Common Wrong Answers? Crowdsourcing Remediation at Scale               100
# 383                                                     M-Powering Teachers: Natural Language Processing Powered Feedback Improves 1:1 Instruction and Student Outcomes                                                     M-Powering Teachers: Natural Language Processing Powered Feedback Improves 1:1 Instruction and Student Outcomes               100
# 300                                                                                            How Do Professors Format Exams? An Analysis of Question Variety at Scale                                                                                            How Do professors format exams? an analysis of question variety at scale               100
# 382                                                  Assessing the Fairness of Course Success Prediction Models in the Face of (Un)equal Demographic Group Distribution                                                  Assessing the Fairness of Course Success Prediction Models in the Face of (Un)equal Demographic Group Distribution               100
# 381                                                                                        All A-board: Sharing Educational Data Science Research With School Districts                                                                                        All A-board: Sharing Educational Data Science Research with School Districts               100
# 301                                                                                                            OARS: Exploring Instructor Analytics for Online Learning                                                                                                            OARS: Exploring instructor analytics for online learning               100
# 379                                                                                                 LENS: Predictive Diagnostics for Flexible and Efficient Assessments                                                                                                 LENS: Predictive Diagnostics for Flexible and Efficient Assessments               100
# 390  How Learning Experience Designers Make Design Decisions: The Role of Data, the Reliance on Subject Matter Expertise, and the Opportunities for Data-Driven Support  How Learning Experience Designers Make Design Decisions: The Role of Data, the Reliance on Subject Matter Expertise, and the Opportunities for Data-Driven Support               100
# 378                                                                                                 Investigating the Impact of Skill-Related Videos on Online Learning                                                                                                 Investigating the Impact of Skill-Related Videos on Online Learning               100
# 377                                                                                                                      Achievements for building a learning community                                                                                                                      Achievements for building a learning community               100
# 303                                                            Codemotion: Expanding the Design Space of Learner Interactions with Computer Programming Tutorial Videos                                                            Codemotion: Expanding the design space of learner interactions with computer programming tutorial videos               100
# 376                                                                                                 Supporting Instruction of Formulaic Sequences Using Videos at Scale                                                                                                 Supporting instruction of formulaic sequences using videos at scale               100
# 304                                                                                   Elicast: Embedding Interactive Exercises in Instructional Programming Screencasts                                                                                   Elicast: Embedding interactive exercises in instructional programming screencasts               100
# 374                                                                                                                   WOSView Demo: A Tool to Explore the Web of Slides                                                                                                                   Wosview Demo: A tool to explore the web of slides               100
# 373                                                                                         Web of Slides: Automatic Linking of Lecture Slides to Facilitate Navigation                                                                                         Web of slides: Automatic linking of lecture slides to facilitate navigation               100
# 305                                                                                               Toward CS1 at Scale: Building and Testing a MOOC-for-Credit Candidate                                                                                               Toward CS1 at Scale: Building and testing a mooc-for-credit candidate               100
# 372                                                                                                             Developing an Intervention to Advance Learning At Scale                                                                                                             Developing an intervention to advance learning at scale               100
# 371                                                                             Jack Watson: Addressing Contract Cheating at Scale in Online Computer Science Education                                                                             Jack Watson: Addressing contract cheating at scale in online computer science education               100
# 302                                                             The Potential of Interdisciplinarity in MOOC Research: How Do Education and Computer Science Intersect?                                                             The Potential of Interdisciplinarity in MOOC Research: How do education and computer science intersect?               100
# 297                                                             The Relationship between Scientific Explanations and the Proficiencies of Content, Inquiry, and Writing                                                             The Relationship between scientific explanations and the proficiencies of content, inquiry, and writing               100
# 321                                                                                                              Can a diversity statement increase diversity in MOOCs?                                                                                                              Can a diversity statement increase diversity in MOOCs?               100
# 306                                                                     Effects of Automated Interventions in Programming Assignments: Evidence from a Field Experiment                                                                     Effects of automated interventions in programming assignments: Evidence from a field experiment               100
# 415                                                                                                                            Challenges of Online Learning in Nigeria                                                                                                                            Challenges of Online Learning in Nigeria               100
# 293                                                                                         Towards Domain General Detection of Transactive Knowledge Building Behavior                                                                                         Towards domain general detection of transactive knowledge building behavior               100
# 414                                                                            Building an Infrastructure for Computer Science Education Research and Practice at Scale                                                                            Building an Infrastructure for Computer Science Education Research and Practice at Scale               100
# 413                                                                                                                                 BELT: Bluejeans codE Leak deTection                                                                                                                                 BELT: Bluejeans codE Leak deTection               100
# 412                                                                                        Automatic RNN Cell Design for Knowledge Tracing using Reinforcement Learning                                                                                        Automatic RNN Cell Design for Knowledge Tracing using Reinforcement Learning               100
# 411                                                                                                                     Automated Generation of Learning Paths at Scale                                                                                                                     Automated Generation of Learning Paths at Scale               100
# 410                                                                                                           Artificial Intelligence for Video-based Learning at Scale                                                                                                           Artificial Intelligence for Video-based Learning at Scale               100
# 409                                                                                              Analyzing Pre-Existing Knowledge and Performance in a Programming MOOC                                                                                              Analyzing Pre-Existing Knowledge and Performance in a Programming MOOC               100
# 408                                                                                                                      Analyzing K-12 Blended MOOC Learning Behaviors                                                                                                                      Analyzing K-12 Blended MOOC Learning Behaviors               100
# 407                                                                                                                 Analysis of Grading Times of Short Answer Questions                                                                                                                 Analysis of Grading Times of Short Answer Questions               100
# 406                                                                                               An Evidence-Based Learner Model for Supporting Activities in Robotics                                                                                               An Evidence-Based Learner Model for Supporting Activities in Robotics               100
# 296                                                                                                                          Refocusing the Lens on Engagement in MOOCs                                                                                                                          Refocusing the lens on engagement in MOOCs               100
# 405                                                                                  AlgoPlan: Supporting Planning in Algorithmic Problem-Solving with Subgoal Diagrams                                                                                  AlgoPlan: Supporting Planning in Algorithmic Problem-Solving with Subgoal Diagrams               100
# 403                                                                                                                  Adaptive Learning using Finite State Machine Logic                                                                                                                  Adaptive Learning using Finite State Machine Logic               100
# 402                                                     A Quantitative Analysis of When Students Choose to Grade Questions on Computerized Exams with Multiple Attempts                                                     A Quantitative Analysis of When Students Choose to Grade Questions on Computerized Exams with Multiple Attempts               100
# 401                                                                                                  A Novel Approach for Knowledge State Representation and Prediction                                                                                                  A Novel Approach for Knowledge State Representation and Prediction               100
# 400                                                                   Supporting Online Collaborative Work at Scale: A Mixed-Methods Study of a Learning Analytics Tool                                                                   Supporting Online Collaborative Work at Scale: A Mixed-Methods Study of a Learning Analytics Tool               100
# 399                                                                                                            GPTeach: Interactive TA Training with GPT-based Students                                                                                                            GPTeach: Interactive TA Training with GPT-based Students               100
# 398                                                               Convincing the Expert: Reducing Algorithm Aversion in Administrative Higher Education Decision-making                                                               Convincing the Expert: Reducing Algorithm Aversion in Administrative Higher Education Decision-making               100
# 397                                                                         EliRank: A Code Editing History Based Ranking Model for Early Detection of Students in Need                                                                         EliRank: A Code Editing History Based Ranking Model for Early Detection of Students in Need               100
# 396                                                       Evaluating a Learned Admission-Prediction Model as a Replacement for Standardized Tests in College Admissions                                                       Evaluating a Learned Admission-Prediction Model as a Replacement for Standardized Tests in College Admissions               100
# 395                                                                                                  Exploring Cross-Country Prediction Model Generalizability in MOOCs                                                                                                  Exploring Cross-Country Prediction Model Generalizability in MOOCs               100
# 394                                                             How to Open Science: Analyzing the Open Science Statement Compliance of the Learning @ Scale Conference                                                             How to Open Science: Analyzing the Open Science Statement Compliance of the Learning @ Scale Conference               100
# 393                                                 Benefit of Gamification for Persistent Learners: Propensity to Replay Problems Moderates Algebra-Game Effectiveness                                                 Benefit of Gamification for Persistent Learners: Propensity to Replay Problems Moderates Algebra-Game Effectiveness               100
# 294                                                     Docent: Transforming personal intuitions to scientific hypotheses through content learning and process training                                                     Docent: Transforming personal intuitions to scientific hypotheses through content learning and process training               100
# 392                                                                    How Teachers Influence Student Adoption and Effectiveness of a Recommendation System for Algebra                                                                    How Teachers Influence Student Adoption and Effectiveness of a Recommendation System for Algebra               100
# 369                                                                          Investigating Learning Design Categorization and Learning Behaviour in Computational MOOCS                                                                          Investigating learning design categorization and learning behaviour in computational MOOCs               100
# 322                                                                              Multiplatform MOOC Analytics: Comparing Global and Regional Patterns in edX and Edraak                                                                              Multiplatform MOOC analytics: Comparing global and regional patterns in EDX and Edraak               100
# 343                                                                                       Predict and Intervene: Addressing the Dropout Problem in a MOOC-based Program                                                                                       Predict and intervene: Addressing the dropout problem in a MOOC-based program               100
# 342                                                                                                                        Via: Illuminating Academic Pathways at Scale                                                                                                                        VIA: Illuminating academic pathways at scale               100
# 341                                                                                              Data-Assistive Course-to-Course Articulation Using Machine Translation                                                                                              Data-assistive course-to-course articulation using machine translation               100
# 340                                                                                                  Master’s at Scale: Five Years in a Scalable Online Graduate Degree                                                                                                  Master’s at scale: Five years in a scalable online graduate degree               100
# 316                                                                          Information Overload and Online Collaborative Learning: Insights from Agent-Based Modeling                                                                          Information overload and online collaborative learning: Insights from agent-based modeling               100
# 339                                                                                              Key Phrase Extraction for Generating Educational Question-Answer Pairs                                                                                              Key phrase extraction for generating educational question-answer pairs               100
# 338                                                                 Apples to Apples: Differences in Viewer Retention When Longer Content is Chopped into Smaller Bites                                                                 Apples to apples: Differences in viewer retention when longer content is chopped into smaller bites               100
# 337                                                                                             Two views of scale: Design Principles for Scaling Reach and Empowerment                                                                                             Two views of scale: Design principles for scaling reach and empowerment               100
# 336                                                                            UpGrade: Sourcing Student Open-Ended Solutions to Create Scalable Learning Opportunities                                                                            Upgrade: Sourcing student open-ended solutions to create scalable learning opportunities               100
# 318                                                                                                                                       Grading at Scale in EarSketch                                                                                                                                       Grading at scale in earsketch               100
# 335                                                                        Scaling Up Writing in the Curriculum: Batch Mode Active Learning for Automated Essay Scoring                                                                        Scaling up writing in the curriculum: Batch mode active learning for automated essay scoring               100
# 319                                              Transformative approaches in distance online education: aligning evidence to influence the design of teaching at scale                                              Transformative approaches in distance online education: Aligning evidence to influence the design of teaching at scale               100
# 334                                                                                                       Mining Students Pre-instruction Beliefs for Improved Learning                                                                                                       Mining students pre-instruction beliefs for improved learning               100
# 333                                                                    Designing Digital Peer Assessment for Second Language Learning in Low Resource Learning Settings                                                                    Designing digital peer assessment for second language learning in low resource learning settings               100
# 332                                                                                                      Automatic Assessment of Complex Assignments using Topic Models                                                                                                      Automatic assessment of complex assignments using topic models               100
# 331                                                                                                                   Inequality: multi-modal equation entry on the web                                                                                                                   Inequality: Multi-modal equation entry on the web               100
# 330                                                        Teaching UI Design at Global Scales: A Case Study of the Design of Collaborative Capstone Projects for MOOCs                                                        Teaching UI design at global scales: A case study of the design of collaborative capstone projects for MOOCs               100
# 329                                                                                                                                  Scaffolding during Science Inquiry                                                                                                                                  Scaffolding during science inquiry               100
# 328                                                                                                               Improv: Teaching Programming at Scale via Live Coding                                                                                                               Improv: Teaching programming at scale via live coding               100
# 327                                                                                         Growth Mindset Predicts Student Achievement and Behavior in Mobile Learning                                                                                         Growth mindset predicts student achievement and behavior in mobile learning               100
# 320                                                                                                Start of a Science: An Epistemological Analysis of Learning at Scale                                                                                                Start of a science: An epistemological analysis of learning at scale               100
# 326                                                   Instructors Desire Student Activity, Literacy, and Video Quality Analytics to Improve Video-based Blended Courses                                                   Instructors desire student activity, literacy, and video quality analytics to improve video-based blended courses               100
# 325                                                                              How Learners Engage with In-Context Retrieval Exercises in Online Informational Videos                                                                              How learners engage with in-context retrieval exercises in online informational videos               100
# 324                                            Graded Team Assignments in MOOCs - Effects of Team Composition and Further Factors on Team Dropout Rates and Performance                                            Graded team assignments in MOOCs - Effects of team composition and further factors on team dropout rates and performance               100
# 323                                                                                       On the Acceptance and Usefulness of Personalized Learning Objectives in MOOCs                                                                                       On the acceptance and usefulness of personalized learning objectives in MOOCs               100
# 315                                                                                                                                   Student Trust in e-Authentication                                                                                                                                   Student trust in e-authentication               100
# 370                                                                          LiveDataLab: A Cloud-Based Platform to Facilitate Hands-on Data Science Education at Scale                                                                          Livedatalab: A cloud-based platform to facilitate hands-on data science education at scale               100
# 345                                                                                                                Measuring Students’ Performance on Programming Tasks                                                                                                                Measuring students’ performance on programming tasks               100
# 314                                                Virtualizing face-2-face trainings for training senior professionals: A Comparative Case Study on Financial Auditors                                                Virtualizing face-2-face trainings for training senior professionals: A comparative case study on financial auditors               100
# 368                                                                                                   Causal Inference in Higher Education: Building Better Curriculums                                                                                                   Causal inference in higher education: Building better curriculums               100
# 367                                                                  PARQR: Augmenting the Piazza Online Forum to Better Support Degree Seeking Online Masters Students                                                                  PaRQR: Augmenting the Piazza online forum to better support degree seeking online masters students               100
# 308                                                                             How Much Randomization is Needed to Deter Collaborative Cheating on Asynchronous Exams?                                                                             How much randomization is needed to deter collaborative cheating on asynchronous exams?               100
# 366                                                                Towards Improving Students’ Forum Posts Categorization in MOOCs and Impact on Performance Prediction                                                                Towards improving students’ forum posts categorization in MOOCs and impact on performance prediction               100
# 364                                                                                                           What do students at distance universities think about AI?                                                                                                           What do students at distance universities think about AI?               100
# 363                                                                                        automaTA: Human-Machine Interaction for Answering Context-Specific Questions                                                                                        Automata: Human-machine interaction for answering context-specific questions               100
# 362                                                                             An Automated Feedback System to Support Student Learning in Writing-to-Learn Activities                                                                             An automated feedback system to support student learning in writing-to-learn activities               100
# 361                                                                                     Guided-KNOWLA: The Use of Guided Unscrambling to Enhance Active Online Learning                                                                                     Guided-Knowla: The use of guided unscrambling to enhance active online learning               100
# 360                                                             Impact of Free-Certificate Coupons on Learner Behavior in Online Courses: Results from Two Case Studies                                                             Impact of free-certificate coupons on learner behavior in online courses: Results from two case studies               100
# 359                                                                Synchronous at Scale: Investigation and Implementation of a Semi-Synchronous Online Lecture Platform                                                                Synchronous at scale: Investigation and implementation of a semi-synchronous online lecture platform               100
# ...
# 153                                                                  Online Urbanism: Interest-based Subcultures as Drivers of Informal Learning in an Online Community                                                                  Online urbanism: Interest-based subcultures as drivers of informal learning in an online community               100
# 152                                                                                                      Observing URL Sharing Behaviour in Massive Online Open Courses                                                                                                      Observing URL sharing behaviour in Massive Online Open Courses               100
# 151                                                                                        Modeling Student Scheduling Preferences in a Computer-Based Testing Facility                                                                                        Modeling student scheduling preferences in a computer-based testing facility               100
# 150                                                                                       Mobile Devices for Early Literacy Intervention and Research with Global Reach                                                                                       Mobile devices for early literacy intervention and research with global reach               100
# 148                                                                                                   Making the Production of Learning at Scale More Open and Flexible                                                                                                   Making the production of learning at scale more open and flexible               100
# 147                                                                        Macro Data for Micro Learning: Developing the FUN! Tool for Automated Assessment of Learning                                                                        Macro data for micro learning: Developing the FUN! Tool for automated assessment of learning               100
# 146                                                                                              Learning at Scale: Using an Evidence Hub To Make Sense of What We Know                                                                                              Learning at scale: Using an Evidence Hub to make sense of what we know               100
# 145                                                                                                             Learning about Teaching in Low-Resource Indian Contexts                                                                                                             Learning about teaching in low-resource Indian contexts               100
# 144                                              Learning Transfer: Does It Take Place in MOOCs? An Investigation into the Uptake of Functional Programming in Practice                                              Learning transfer: Does it take place in moocs? An investigation into the uptake of functional programming in practice               100
# 160                                                                                                                Personalized Adaptive Learning using Neural Networks                                                                                                                Personalized adaptive learning using neural networks               100
# 218                                                                                                 Intelligent Math Tutor: Problem-Based Approach to Create Cognizance                                                                                                 Intelligent math tutor: Problem-based approach to create cognizance               100
# 178                                                                                              Understanding ESL Students' Motivations to Increase MOOC Accessibility                                                                                              Understanding ESL students' motivations to increase MOOC accessibility               100
# 180                                                                                                           Using Multiple Accounts for Harvesting Solutions in MOOCs                                                                                                           Using multiple accounts for harvesting solutions in MOOCs               100
# 216                                                                                                                       In-Video Reuse of Discussion Threads in MOOCs                                                                                                                       In-video reuse of discussion threads in MOOCs               100
# 215                                                                                    Improving Assessment on MOOCs Through Peer Identification and Aligned Incentives                                                                                    Improving assessment on MOOCs through peer identification and aligned incentives               100
# 214     Humans and Machines Together: Improving Characterization of Large Scale Online Discussions through Dynamic Interrelated Post and Thread Categorization (DIPTiC)     Humans and machines together: Improving characterization of large scale online discussions through dynamic interrelated post and thread categorization (DIPTiC)               100
# 213                                                                           Gradescope: A Fast, Flexible, and Fair System for Scalable Assessment of Handwritten Work                                                                           Gradescope: A fast, flexible, and fair system for scalable assessment of handwritten work               100
# 212                                                                                    Google BigQuery for Education: Framework for Parsing and Analyzing edX MOOC Data                                                                                    Google BigQuery for education: Framework for parsing and analyzing edX MOOC data               100
# 210                                                                                Generating Language Activities in Real-Time for English Learners using Language Muse                                                                                Generating language activities in real-Time for english learners using language muse               100
# 209                                                                      Formal Forum Triage: Towards the Strategic Selection of Responses to Student Discussion Forums                                                                      Formal forum triage: Towards the strategic selection of responses to student discussion forums               100
# 208                                                                                    Factor Analysis Reveals Student Thinking using the Mechanics Reasoning Inventory                                                                                    Factor analysis reveals student thinking using the mechanics reasoning inventory               100
# 207                                                                 Experimenting Choices of Video and Text Feedback in Authentic Foreign Language Assignments at Scale                                                                 Experimenting choices of video and text feedback in authentic foreign language assignments at scale               100
# 205                                        Enhancing the Experience Application Program Interface (xAPI) to Improve Domain Competency Modeling for Adaptive Instruction                                        Enhancing the experience application program interface (xAPI) to improve domain competency modeling for adaptive instruction               100
# 204                                                                       Enabling Real-Time Adaptivity in MOOCs with a Personalized Next-Step Recommendation Framework                                                                       Enabling real-Time adaptivity in MOOCs with a personalized next-step recommendation framework               100
# 202                                                                                           Detecting Diligence with Online Behaviors on Intelligent Tutoring Systems                                                                                           Detecting diligence with online behaviors on intelligent tutoring systems               100
# 201                                                                                                                             Designing Adaptive Assessments in MOOCs                                                                                                                             Designing adaptive assessments in MOOCs               100
# 200                                                                                                                     Deep Knowledge Tracing On Programming Exercises                                                                                                                     Deep knowledge tracing on programming exercises               100
# 179                                                                                                 Using Android Wear for Avoiding Procrastination Behaviours in MOOCs                                                                                                 Using Android Wear for avoiding procrastination behaviours in MOOCs               100
# 199                                                                                                        Data-Driven Feedback Generator for Online Programing Courses                                                                                                        Data-driven feedback generator for online programing courses               100
# 196                                                     Congruency, Adaptivity, Modularity, and Personalization: Four Experiments in Teaching Introduction to Computing                                                     Congruency, adaptivity, modularity, and personalization: Four experiments in teaching introduction to computing               100
# 195                                                                                                                Comment Ranking Diversification in Forum Discussions                                                                                                                Comment ranking diversification in forum discussions               100
# 193                                                                                         Characterizing ELL Students' Behavior During MOOC Videos Using Content Type                                                                                         Characterizing ELL students' behavior during mooc videos using content type               100
# 192                                                                                                        CROWDLEARNING: Towards Collaborative Problem-Posing at Scale                                                                                                        CROWDLEARNING: Towards collaborative problem-posing at scale               100
# 191                                                             Authentic Science Inquiry Learning at Scale Enabled by an Interactive Biology Cloud Experimentation Lab                                                             Authentic science inquiry learning at scale enabled by an interactive biology cloud experimentation lab               100
# 190                                                       Applying and Exploring Bayesian Hypothesis Testing for Large Scale Experimentation in Online Tutoring Systems                                                       Applying and exploring Bayesian hypothesis testing for large scale experimentation in online tutoring systems               100
# 189                                                                                                                   Access to Massive Open Online Labs through a MOOC                                                                                                                   Access to massive open online labs through a MOOC               100
# 188                                                        A Visual Approach towards Knowledge Engineering and Understanding How Students Learn in Complex Environments                                                        A visual approach towards knowledge engineering and understanding how students learn in complex environments               100
# 187                                                                                                    A Statistical Framework for Predictive Model Evaluation in MOOCs                                                                                                    A statistical framework for predictive model evaluation in MOOCs               100
# 186                                                                             A Probabilistic Approach for Discovering Difficult Course Topics Using Clickstream Data                                                                             A probabilistic approach for discovering difficult course topics using clickstream data               100
# 185                                                                                                                   A Novel Self-Paced Model for Teaching Programming                                                                                                                   A novel self-paced model for teaching programming               100
# 184                                                                                                               A Memory-Augmented Neural Model for Automated Grading                                                                                                               A memory-Augmented neural model for automated grading               100
# 183                                                                               A Heuristic Method for Large-Scale Cognitive-Diagnostic Computerized Adaptive Testing                                                                               A heuristic method for large-scale cognitive-diagnostic computerized adaptive testing               100
# 181                                                                     Work in Progress: Student Behaviors Using Feedback in a Blended Physics Undergraduate Classroom                                                                     Work in progress: Student behaviors using feedback in a blended physics undergraduate classroom               100
# 197                                                                                                                     Criteria for Video Engagement in a Biology MOOC                                                                                                                     Criteria for video engagement in a biology MOOC               100
# 563                                                                                 Utilizing Neural Network to Predict Students Aptitudes for Teaching Assistant Roles                                                                                 Utilizing Neural Network to Predict Students Aptitudes for Teaching Assistant Roles               100

# %%
assert len(merged_df) >= len(prof_df)
