# %%
#import beautifulsoup4
from bs4 import BeautifulSoup
import pandas as pd
import requests
from collections import defaultdict
from pathlib import Path
import os

# %%
"""
    This function gets the html from the dblp website
"""
def get_html(year):
    url = f'https://dblp.org/db/conf/lats/lats{year}.html'

    # get the html
    response = requests.get(url)
    html = response.content

    # extract the html from https://dblp.org/db/conf/lats/lats2017.html
    soup = BeautifulSoup(html, "html.parser")

    return soup

# %%
# Get HTML for relevant years.
# Since I was tasked with 2016, 2017 and 2022 I retrieved the HTML for those years
soup_2016 = get_html(2016) 
soup_2017 = get_html(2017)
soup_2022 = get_html(2022)

# %%
"""
    This function creates creates adds a row to the dataframe for each paper.
    Each row contains the following columns:
        - Year
        - Session Name
        - Full Paper or WIP?
        - Authors
        - Paper Title
        - First Author Last Name
        - First Author First Name
        - Link
        - DOI
        - File Name
"""

def add_rows(df, soup, year):
    # Find the "ul class='publ-list" immediately after each H2. 
    for ul in soup.find_all("ul", class_="publ-list"):
        
        # Then loop through each "li class='entry inproceedings'" and print out the text
        for li in ul.find_all("li", class_="entry inproceedings"):
            paper_dict = defaultdict(str)
            paper_dict['Year'] = year 
            paper_dict['Session Name'] = li.find_previous('h2').text
            
            # Ignore keynote and demonstrations. You might need to add more, like Tutorials, Posters and Workshops that you'd like to ignore
            if paper_dict['Session Name'] in ['Keynote Address', 'Demonstrations']:
                continue

            if paper_dict['Session Name'] == 'Work in Progress':
                paper_dict['Full Paper or WIP?'] = 'WIP'
            else:
                paper_dict['Full Paper or WIP?'] = 'Full Paper'
            
            for cite in li.find_all("cite"):
                paper_dict['Authors'] = cite.text.split(':')[0]
                paper_dict['Paper Title'] = ':'.join(cite.text.split(':')[1:]).strip().split('.')[0]
                
                first_author = paper_dict['Authors'].split(',')[0]
                
                paper_dict['First Author Last Name'] = first_author.split(' ')[-1]
                
                paper_dict['First Author First Name'] = ' '.join(first_author.split(' ')[:-1])
                
            for nav_publ in li.find_all("nav", class_="publ"):
                for dropdown in nav_publ.find_all("li", class_="drop-down"):
                    for div in dropdown.find_all("div", class_="head"):
                        for a in div.find_all("a"):
                            if 'https://doi.org' in a['href']:

                                paper_dict['Link'] = a['href']
                                paper_dict['DOI']  = a['href'].split('https://doi.org/')[1]
                                paper_dict['Link'] = 'https://dl.acm.org/doi/pdf/' + paper_dict['DOI'] 

                                paper_dict['File Name'] = f'{year}_{paper_dict["Paper Title"]}.pdf'
                        
                # Add row to dataframe
                df = pd.concat([df,pd.DataFrame([paper_dict])], ignore_index=True)
    return df

# %%
# Create and populate the dataframe with relevant papers
columns = ['First Author First Name','First Author Last Name','Paper Title','Year',	'Full Paper or WIP?','Session Name','Authors','Link','File Name','DOI']
df = pd.DataFrame(columns=columns)
df=add_rows(df, soup_2016, 2016)
df=add_rows(df, soup_2017, 2017)
df=add_rows(df, soup_2022, 2022)
display(df)
# Out:
#     First Author First Name First Author Last Name  \
# 0                    Justin                  Reich
# 1                   Cynthia               Breazeal
# 2                    Ben U.                 Gelman
# 3                      Geza                 Kovacs
# 4                   Eleanor               O'Rourke
# ..                      ...                    ...
# 208                  Dragos             Corlatescu
# 209                  Robert                Stanyon
# 210             Danielle R.                  Chine
# 211                   Scott                  Bunin
# 212                     Dan                 Garcia
#
#                                            Paper Title  Year  \
# 0    The Civic Mission of MOOCs: Measuring Engageme...  2016
# 1    Mobile Devices for Early Literacy Intervention...  2016
# 2    Online Urbanism: Interest-based Subcultures as...  2016
# 3    Effects of In-Video Quizzes on MOOC Lecture Vi...  2016
# 4    Brain Points: A Deeper Look at a Growth Mindse...  2016
# ..                                                 ...   ...
# 208  Where are the Large N Studies in Education?: I...  2022
# 209  Demo of Graide: AI Powered Assistive Grading E...  2022
# 210  Development of Scenario-based Mentor Lessons: ...  2022
# 211  Incorporating Habitats in Conceptual Models an...  2022
# 212                 Software Support for "A's for All"  2022
#
#     Full Paper or WIP?      Session Name  \
# 0           Full Paper    Global Village
# 1           Full Paper    Global Village
# 2           Full Paper    Global Village
# 3           Full Paper        Engagement
# 4           Full Paper        Engagement
# ..                 ...               ...
# 208                WIP  Work in Progress
# 209         Full Paper             Demos
# 210         Full Paper             Demos
# 211         Full Paper             Demos
# 212         Full Paper             Demos
#
#                                                Authors  \
# 0    Justin Reich, Brandon M. Stewart, Kimia Mavon,...
# 1    Cynthia Breazeal, Robin Morris, Stephanie Gott...
# 2    Ben U. Gelman, Chris Beckley, Aditya Johri, Ca...
# 3                                          Geza Kovacs
# 4    Eleanor O'Rourke, Erin Peach, Carol S. Dweck, ...
# ..                                                 ...
# 208  Dragos Corlatescu, Stefan Ruseti, Irina Toma, ...
# 209  Robert Stanyon, Enrico Martello, Manjinder Kai...
# 210  Danielle R. Chine, Pallavi Chhabra, Adetunji A...
# 211  Scott Bunin, Willventchy Celestin, Andrew Horn...
# 212  Dan Garcia, Connor McMahon, Yuan Garcia, Matth...
#
#                                                   Link  \
# 0    https://dl.acm.org/doi/pdf/10.1145/2876034.287...
# 1    https://dl.acm.org/doi/pdf/10.1145/2876034.287...
# 2    https://dl.acm.org/doi/pdf/10.1145/2876034.287...
# 3    https://dl.acm.org/doi/pdf/10.1145/2876034.287...
# 4    https://dl.acm.org/doi/pdf/10.1145/2876034.287...
# ..                                                 ...
# 208  https://dl.acm.org/doi/pdf/10.1145/3491140.352...
# 209  https://dl.acm.org/doi/pdf/10.1145/3491140.352...
# 210  https://dl.acm.org/doi/pdf/10.1145/3491140.352...
# 211  https://dl.acm.org/doi/pdf/10.1145/3491140.352...
# 212  https://dl.acm.org/doi/pdf/10.1145/3491140.352...
#
#                                              File Name  \
# 0    2016_The Civic Mission of MOOCs: Measuring Eng...
# 1    2016_Mobile Devices for Early Literacy Interve...
# 2    2016_Online Urbanism: Interest-based Subcultur...
# 3    2016_Effects of In-Video Quizzes on MOOC Lectu...
# 4    2016_Brain Points: A Deeper Look at a Growth M...
# ..                                                 ...
# 208  2022_Where are the Large N Studies in Educatio...
# 209  2022_Demo of Graide: AI Powered Assistive Grad...
# 210  2022_Development of Scenario-based Mentor Less...
# 211  2022_Incorporating Habitats in Conceptual Mode...
# 212        2022_Software Support for "A's for All".pdf
#
#                          DOI
# 0    10.1145/2876034.2876045
# 1    10.1145/2876034.2876046
# 2    10.1145/2876034.2876052
# 3    10.1145/2876034.2876041
# 4    10.1145/2876034.2876040
# ..                       ...
# 208  10.1145/3491140.3528315
# 209  10.1145/3491140.3528263
# 210  10.1145/3491140.3528262
# 211  10.1145/3491140.3528261
# 212  10.1145/3491140.3528260
#
# [213 rows x 10 columns]

# %%
# By default, the name of the downloaded file from Chrome is the DOI. 
# Adding this in for later
df['Original File Name']  = df['DOI'].str.split('/').str[-1]+'.pdf'

# Drop ("Year == 2022" and "Full Paper or WIP? == Full Paper) since that is not my part
df = df.drop(df[(df['Year'] == 2022) & (df['Full Paper or WIP?'] == 'Full Paper')].index)

df.sort_values('File Name', inplace=True)

# Export the file
df.to_csv('./output/2016_2017_2022.csv', index=False)

display(df)
# Out:
#     First Author First Name First Author Last Name  \
# 8                      Adam            Stankiewicz
# 34                Meen Chul                    Kim
# 68          Mohammad Hassan             Falakmasir
# 37                 Thushari               Atapattu
# 38                     Anna                Kasunic
# ..                      ...                    ...
# 203                   Pablo           García-Zarza
# 204                Jungwook                   Rhim
# 206                      Yu                     Li
# 205                 Zachary                 Felker
# 208                  Dragos             Corlatescu
#
#                                            Paper Title  Year  \
# 8    $1 Conversational Turn Detector: Measuring How...  2016
# 34   A Constructionist Toolkit for Learning Element...  2016
# 68   A Data-Driven Approach for Inferring Student P...  2016
# 37   A Framework for Topic Generation and Labeling ...  2016
# 38   A Preliminary Look at MOOC-associated Facebook...  2016
# ..                                                 ...   ...
# 203  Towards a Teacher Application to Support Seman...  2022
# 204  Understanding the Relationship Between Student...  2022
# 206                  Using Chatbots to Teach Languages  2022
# 205  Using a Planning Prompt Survey to Encourage Ea...  2022
# 208  Where are the Large N Studies in Education?: I...  2022
#
#     Full Paper or WIP?          Session Name  \
# 8           Full Paper     Learner Modelling
# 34                 WIP      Work in Progress
# 68          Full Paper  Automated Assessment
# 37                 WIP      Work in Progress
# 38                 WIP      Work in Progress
# ..                 ...                   ...
# 203                WIP      Work in Progress
# 204                WIP      Work in Progress
# 206                WIP      Work in Progress
# 205                WIP      Work in Progress
# 208                WIP      Work in Progress
#
#                                                Authors  \
# 8                   Adam Stankiewicz, Chinmay Kulkarni
# 34   Meen Chul Kim, Thomas H. Park, Brian Lee, Sukr...
# 68   Mohammad Hassan Falakmasir, José P. González-B...
# 37                  Thushari Atapattu, Katrina Falkner
# 38   Anna Kasunic, Jessica Hammer, Robert E. Kraut,...
# ..                                                 ...
# 203  Pablo García-Zarza, Miguel L. Bote-Lorenzo, Gu...
# 204                       Jungwook Rhim, Gahgene Gweon
# 206  Yu Li, Chun-Yen Chen, Dian Yu, Sam Davidson, R...
# 205                     Zachary Felker, Zhongzhou Chen
# 208  Dragos Corlatescu, Stefan Ruseti, Irina Toma, ...
#
#                                                   Link  \
# 8    https://dl.acm.org/doi/pdf/10.1145/2876034.287...
# 34   https://dl.acm.org/doi/pdf/10.1145/2876034.289...
# 68   https://dl.acm.org/doi/pdf/10.1145/2876034.287...
# 37   https://dl.acm.org/doi/pdf/10.1145/2876034.289...
# 38   https://dl.acm.org/doi/pdf/10.1145/2876034.289...
# ..                                                 ...
# 203  https://dl.acm.org/doi/pdf/10.1145/3491140.352...
# 204  https://dl.acm.org/doi/pdf/10.1145/3491140.352...
# 206  https://dl.acm.org/doi/pdf/10.1145/3491140.352...
# 205  https://dl.acm.org/doi/pdf/10.1145/3491140.352...
# 208  https://dl.acm.org/doi/pdf/10.1145/3491140.352...
#
#                                              File Name  \
# 8    2016_$1 Conversational Turn Detector: Measurin...
# 34   2016_A Constructionist Toolkit for Learning El...
# 68   2016_A Data-Driven Approach for Inferring Stud...
# 37   2016_A Framework for Topic Generation and Labe...
# 38   2016_A Preliminary Look at MOOC-associated Fac...
# ..                                                 ...
# 203  2022_Towards a Teacher Application to Support ...
# 204  2022_Understanding the Relationship Between St...
# 206         2022_Using Chatbots to Teach Languages.pdf
# 205  2022_Using a Planning Prompt Survey to Encoura...
# 208  2022_Where are the Large N Studies in Educatio...
#
#                          DOI   Original File Name
# 8    10.1145/2876034.2876048  2876034.2876048.pdf
# 34   10.1145/2876034.2893411  2876034.2893411.pdf
# 68   10.1145/2876034.2876038  2876034.2876038.pdf
# 37   10.1145/2876034.2893414  2876034.2893414.pdf
# 38   10.1145/2876034.2893415  2876034.2893415.pdf
# ..                       ...                  ...
# 203  10.1145/3491140.3528335  3491140.3528335.pdf
# 204  10.1145/3491140.3528311  3491140.3528311.pdf
# 206  10.1145/3491140.3528329  3491140.3528329.pdf
# 205  10.1145/3491140.3528297  3491140.3528297.pdf
# 208  10.1145/3491140.3528315  3491140.3528315.pdf
#
# [182 rows x 11 columns]

# %%
# NOTE: Manual steps required!!
# After running this step, we cannot automatically download the paper
# This is because of the authentication required.
# Thus, I manually opened each paper link in the dataframe and saved it to the "papers" folder
# I used the chrome extension "Open Multiple URLs" to open all the links at once.
# I then used the chrome extension "Download All PDFs" to download all the papers at once with the default name.

# %%
# Check if papers downloaded is correct
files = os.listdir('./papers')

assert len(files) == len(df), f'Number of files downloaded ({len(files)}) does not match number of papers ({len(df)})'
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[39], line 4
#       1 # Check if papers downloaded is correct
#       2 files = os.listdir('./papers')
# ----> 4 assert len(files) == len(df), f'Number of files downloaded ({len(files)}) does not match number of papers ({len(df)})'
#
# AssertionError: Number of files downloaded (179) does not match number of papers (182)

# %%
# Script to rename the file name from "Original File Name" (DOI) to "File Name" (required by Dr Duncan)
import os

# Find all files in "./papers"
files = os.listdir('./papers')

# Loop through each file
for file in files:

    # Find the row in the dataframe that matches the file
    row = df[df['Original File Name'] == file]

    # If there is a match, rename the file
    if len(row) > 0:
        os.rename(f'./papers/{file}', f'./papers/{row["File Name"].values[0]}')

# %%
# Remove all "/ \ < > : * " ? |" from the file names in "papers"
# Such characters will cause upload to Onedrive to fail

# Find all files in "./papers"
files = os.listdir('./papers')

# Loop through each file
for file in files:

    # Replace all "/ \ < > : * " ? $ |" with ""
    new_file = file.replace('/','').replace('\\','').replace('<','').replace('>','').replace(':','').replace('*','').replace('"','').replace('?','').replace('|','')

    # If the file name has changed, rename the file
    if file != new_file:
        os.rename(f'./papers/{file}', f'./papers/{new_file}')

# %%
# # Do fuzzy string matching to find papers missing
# # This is because some papers have different names in the dataframe and in the file name
# from thefuzz import fuzz

# # Find all files that does not have a fuzzymatched filename
# # Find all files in "./papers"
# files = os.listdir('./papers')

# # Loop through each file
# for file in files:

#     # Find the highest fuzzymatch score 
#     # (i.e. the paper with the highest similarity to the file name)
#     score = df['File Name'].apply(lambda x: fuzz.ratio(x, file)).max()

#     # Find the row in the dataframe that matches the file
#     row = df[df['File Name'].apply(lambda x: fuzz.ratio(x, file)) == score]

#     # If score <0.9, then print file name
#     if score < 90:
#         print(file, row, score)

# %%
# # Remove files that do not appear in this dataframe
# # (use by travis to remove unnecessary papers)
# files = os.listdir('./papers')

# # Loop through each file
# for file in files:

#     # Find the row in the dataframe that matches the file
#     row = df[df['File Name'] == file]

#     # If there is no match, delete the file
#     if len(row) == 0:
#         os.remove(f'./papers/{file}')

#         print('deleted')
# Out:
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
# deleted
